# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("cardekho_dataset.csv")

# %%
data
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
data.drop({'Unnamed: 0','car_name','brand','max_power'},axis=1,inplace=True)

# %%
data
# Out:
#           model  vehicle_age  km_driven seller_type fuel_type  \
# 0          Alto            9     120000  Individual    Petrol
# 1         Grand            5      20000  Individual    Petrol
# 2           i20           11      60000  Individual    Petrol
# 3          Alto            9      37000  Individual    Petrol
# 4      Ecosport            6      30000      Dealer    Diesel
# ...         ...          ...        ...         ...       ...
# 15406       i10            9      10723      Dealer    Petrol
# 15407    Ertiga            2      18000      Dealer    Petrol
# 15408     Rapid            6      67000      Dealer    Diesel
# 15409    XUV500            5    3800000      Dealer    Diesel
# 15410      City            2      13000      Dealer    Petrol
#
#       transmission_type  mileage  engine  seats  selling_price
# 0                Manual    19.70     796      5         120000
# 1                Manual    18.90    1197      5         550000
# ...

# %%
data['model'].unique()
# Out:
# array(['Alto', 'Grand', 'i20', 'Ecosport', 'Wagon R', 'i10', 'Venue',
#        'Swift', 'Verna', 'Duster', 'Cooper', 'Ciaz', 'C-Class', 'Innova',
#        'Baleno', 'Swift Dzire', 'Vento', 'Creta', 'City', 'Bolero',
#        'Fortuner', 'KWID', 'Amaze', 'Santro', 'XUV500', 'KUV100', 'Ignis',
#        'RediGO', 'Scorpio', 'Marazzo', 'Aspire', 'Figo', 'Vitara',
#        'Tiago', 'Polo', 'Seltos', 'Celerio', 'GO', '5', 'CR-V',
#        'Endeavour', 'KUV', 'Jazz', '3', 'A4', 'Tigor', 'Ertiga', 'Safari',
#        'Thar', 'Hexa', 'Rover', 'Eeco', 'A6', 'E-Class', 'Q7', 'Z4', '6',
#        'XF', 'X5', 'Hector', 'Civic', 'D-Max', 'Cayenne', 'X1', 'Rapid',
#        'Freestyle', 'Superb', 'Nexon', 'XUV300', 'Dzire VXI', 'S90',
#        'WR-V', 'XL6', 'Triber', 'ES', 'Wrangler', 'Camry', 'Elantra',
#        'Yaris', 'GL-Class', '7', 'S-Presso', 'Dzire LXI', 'Aura', 'XC',
#        'Ghibli', 'Continental', 'CR', 'Kicks', 'S-Class', 'Tucson',
# ...

# %%
data['transmission_type']=data['transmission_type'].replace('Manual',1)
data['transmission_type']=data['transmission_type'].replace('Automatic',2)
# Out:
# /var/folders/qc/scwc6f4109jcdlk464h39b1m0000gn/T/ipykernel_4251/527857980.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['transmission_type']=data['transmission_type'].replace('Automatic',2)

# %%
data['fuel_type']=data['fuel_type'].replace('Petrol',1)
data['fuel_type']=data['fuel_type'].replace('Diesel',2)
data['fuel_type']=data['fuel_type'].replace('CNG',3)
data['fuel_type']=data['fuel_type'].replace('LPG',4)
data['fuel_type']=data['fuel_type'].replace('Electric',5)
# Out:
# /var/folders/qc/scwc6f4109jcdlk464h39b1m0000gn/T/ipykernel_4251/2473891017.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['fuel_type']=data['fuel_type'].replace('Electric',5)

# %%
data['seller_type']=data['seller_type'].replace('Individual',1)
data['seller_type']=data['seller_type'].replace('Dealer',2)
data['seller_type']=data['seller_type'].replace('Trustmark Dealer',3)
# Out:
# /var/folders/qc/scwc6f4109jcdlk464h39b1m0000gn/T/ipykernel_4251/2100541241.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['seller_type']=data['seller_type'].replace('Trustmark Dealer',3)

# %%
j=1
for i in data['model'].unique():    
    data['model']=data['model'].replace(i,j)
    print(i,j)
    j=j+1
# Out:
# Alto 1
# Grand 2
# i20 3
# Ecosport 4
# Wagon R 5
# i10 6
# Venue 7
# Swift 8
# Verna 9
# Duster 10
# Cooper 11
# Ciaz 12
# C-Class 13
# Innova 14
# Baleno 15
# Swift Dzire 16
# Vento 17
# Creta 18
# City 19
# Bolero 20
# Fortuner 21
# KWID 22
# Amaze 23
# Santro 24
# XUV500 25
# KUV100 26
# Ignis 27
# RediGO 28
# Scorpio 29
# Marazzo 30
# Aspire 31
# Figo 32
# Vitara 33
# Tiago 34
# Polo 35
# Seltos 36
# Celerio 37
# GO 38
# 5 39
# CR-V 40
# Endeavour 41
# KUV 42
# Jazz 43
# 3 44
# A4 45
# Tigor 46
# Ertiga 47
# Safari 48
# Thar 49
# Hexa 50
# Rover 51
# Eeco 52
# A6 53
# E-Class 54
# Q7 55
# Z4 56
# 6 57
# XF 58
# X5 59
# Hector 60
# Civic 61
# D-Max 62
# Cayenne 63
# X1 64
# Rapid 65
# Freestyle 66
# Superb 67
# Nexon 68
# XUV300 69
# Dzire VXI 70
# S90 71
# WR-V 72
# XL6 73
# Triber 74
# ES 75
# Wrangler 76
# Camry 77
# Elantra 78
# Yaris 79
# GL-Class 80
# 7 81
# S-Presso 82
# Dzire LXI 83
# Aura 84
# XC 85
# Ghibli 86
# Continental 87
# CR 88
# Kicks 89
# S-Class 90
# ...

# %%
data
# Out:
#        model  vehicle_age  km_driven  seller_type  fuel_type  \
# 0          1            9     120000            1          1
# 1          2            5      20000            1          1
# 2          3           11      60000            1          1
# 3          1            9      37000            1          1
# 4          4            6      30000            2          2
# ...      ...          ...        ...          ...        ...
# 15406      6            9      10723            2          1
# 15407     47            2      18000            2          1
# 15408     65            6      67000            2          2
# 15409     25            5    3800000            2          2
# 15410     19            2      13000            2          1
#
#        transmission_type  mileage  engine  seats  selling_price
# 0                      1    19.70     796      5         120000
# 1                      1    18.90    1197      5         550000
# ...

# %%
data.describe()
# Out:
#               model   vehicle_age     km_driven   seller_type     fuel_type  \
# count  15411.000000  15411.000000  1.541100e+04  15411.000000  15411.000000
# mean      23.265654      6.036338  5.561648e+04      1.641425      1.530076
# std       21.235108      3.013291  5.161855e+04      0.502461      0.555359
# min        1.000000      0.000000  1.000000e+02      1.000000      1.000000
# 25%        8.000000      4.000000  3.000000e+04      1.000000      1.000000
# 50%       17.000000      6.000000  5.000000e+04      2.000000      2.000000
# 75%       33.000000      8.000000  7.000000e+04      2.000000      2.000000
# max      120.000000     29.000000  3.800000e+06      3.000000      5.000000
#
#        transmission_type       mileage        engine         seats  \
# count       15411.000000  15411.000000  15411.000000  15411.000000
# mean            1.206735     19.701151   1486.057751      5.325482
# std             0.404977      4.171265    521.106696      0.807628
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr_mat=data.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr_mat,annot=True)
# Out:
# <Axes: >

# %%
x=data[['model','vehicle_age','km_driven','seller_type','fuel_type','transmission_type','mileage','engine','seats']]
y=data['selling_price']

# %%
x
# Out:
#        model  vehicle_age  km_driven  seller_type  fuel_type  \
# 0          1            9     120000            1          1
# 1          2            5      20000            1          1
# 2          3           11      60000            1          1
# 3          1            9      37000            1          1
# 4          4            6      30000            2          2
# ...      ...          ...        ...          ...        ...
# 15406      6            9      10723            2          1
# 15407     47            2      18000            2          1
# 15408     65            6      67000            2          2
# 15409     25            5    3800000            2          2
# 15410     19            2      13000            2          1
#
#        transmission_type  mileage  engine  seats
# 0                      1    19.70     796      5
# 1                      1    18.90    1197      5
# 2                      1    17.00    1197      5
# ...

# %%
y
# Out:
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000
#           ...
# 15406     250000
# 15407     925000
# 15408     425000
# 15409    1225000
# 15410    1200000
# Name: selling_price, Length: 15411, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
model.predict([[19,1,4500,2,1,2,18.40,1498,5]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([1262020.])

# %%
X_test
# Out:
#        model  vehicle_age  km_driven  seller_type  fuel_type  \
# 3334       6           12      73000            2          1
# 10928     15            4      58000            1          2
# 2518      47            7      96000            2          2
# 11322     19            1       4500            2          1
# 9394       1           11      62000            2          1
# ...      ...          ...        ...          ...        ...
# 1943      35            9      38000            2          2
# 10471     23            2       8000            2          1
# 13098     23            2       2200            2          1
# 6545       5            3      30000            1          1
# 14377      3            2      16000            2          2
#
#        transmission_type  mileage  engine  seats
# 3334                   1    20.36    1197      5
# 10928                  1    27.39    1248      5
# 2518                   1    20.77    1248      7
# ...

# %%
y_test
# Out:
# 3334      190000
# 10928     600000
# 2518      665000
# 11322    1570000
# 9394      160000
#           ...
# 1943      295000
# 10471     840000
# 13098     790000
# 6545      440000
# 14377     861000
# Name: selling_price, Length: 3083, dtype: int64

# %%
import joblib
joblib.dump(model, 'car_price_model.pkl')
# Out:
# ['car_price_model.pkl']
